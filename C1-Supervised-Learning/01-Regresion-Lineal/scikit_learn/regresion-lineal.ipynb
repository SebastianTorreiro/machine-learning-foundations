# %%
from sklearn.linear_model import SGDRegressor

X = np.array([[1], [2], [3]])
y_real = np.array([[2], [4], [6]]).ravel()
x_nuevo = np.array([[4], [3], [3]])

model = SGDRegressor(eta0=0.31, max_iter=1000)
model.fit(X, y_real)
predicciones_nuevitas = model.predict(x_nuevo)
print(predicciones_nuevitas)
